# %%
import os
import numpy as np 
import pandas as pd

from matplotlib.pyplot import imread

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = "../raw_data"

img_path = os.path.join(path, "images", "guatemala-volcano_00000006_pre_disaster.png")

image = imread(img_path)

# %%
image.shape
# Out:
# (1024, 1024, 3)

# %%
plt.imshow(image)
